# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\chukw\\PycharmProjects\\Kingsley Chika CHUKWU _AcadProject\\Files Folder\\MSc Thesis'

# %%
os.chdir("C:\\Users\\chukw\\PycharmProjects\\Kingsley Chika CHUKWU _AcadProject")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
classes = ['Baresoil', 'Built Area', 'Farmland', 'Vegetation', 'Water']
percent_2000 = [4.29, 4.62, 65.13, 25.33, 0.63]
percent_2010 = [11.54, 14.00, 52.05, 19.23, 3.18]
percent_2020 = [21.06, 22.35, 42.98, 9.49, 4.12]

years = ['2000', '2010', '2020']
x = np.arange(len(classes))
width = 0.2

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width, percent_2000, width, label='2000', color='blue')
rects2 = ax.bar(x, percent_2010, width, label='2010', color='green')
rects3 = ax.bar(x + width, percent_2020, width, label='2020', color='orange')

# Labels and formatting
ax.set_xlabel('Land Cover Class')
ax.set_ylabel('Percentage (%) Changes')
ax.set_title("Land Cover Changes in Rutungo Mining Study Area of Year 2000, 2010 and 2020")
ax.set_xticks(x)
ax.set_xticklabels(classes, rotation=45, ha="right")
ax.legend()
ax.grid(linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# PackagesModules
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-70157675-0930-4aec-8841-e8bfbf46bc78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70157675-0930-4aec-8841-e8bfbf46bc78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Data/UNILAK/Sample Points.csv")
df.shape
# Out:
# (600, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S/No       600 non-null    int64
#  1   Longitude  600 non-null    float64
#  2   Latitude   600 non-null    float64
#  3   Y1517      599 non-null    float64
#  4   Y1921      599 non-null    float64
#  5   Y2325      599 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 28.3 KB

# %%
df.describe()
# Out:
#              S/No   Longitude    Latitude       Y1517       Y1921       Y2325
# count  600.000000  600.000000  600.000000  599.000000  599.000000  599.000000
# mean   300.500000   30.037242   -1.785950    0.218865    0.042328    0.126551
# std    173.349358    0.037456    0.035734    0.142394    0.029271    0.463627
# min      1.000000   29.959390   -1.861490   -0.154340   -0.063530   -0.884980
# 25%    150.750000   30.009183   -1.813817    0.110590    0.022195   -0.264340
# 50%    300.500000   30.036225   -1.787455    0.212830    0.043510    0.175150
# 75%    450.250000   30.062867   -1.756940    0.330895    0.062040    0.479915
# max    600.000000   30.130880   -1.711850    0.543460    0.119670    1.239000

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load CSV
df = pd.read_csv("Data/UNILAK/Sample Points.csv")

# Check column names
print(df.columns)

# indexing
if "index" not in df.columns:
    df["index"] = range(1, len(df) + 1)

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df["index"], df["Y1517"], label="Year 2015 & 2017", color="blue", alpha=0.6)
plt.scatter(df["index"], df["Y1921"], label="Year 2019 & 2021", color="red", alpha=0.6)
plt.scatter(df["index"], df["Y2325"], label="Year 2023 & 2025", color="green", alpha=0.6)

# Formatting the plot
plt.xlabel("Index")
plt.ylabel(" of Deformation ")
plt.title("Scatter Plot of  Ground Deforemation for Year 2015 & 2017, 2019 and 2021, 2023 & 2025")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Index(['S/No', 'Longitude', 'Latitude', 'Y1517', 'Y1921', 'Y2325'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load CSV
df = pd.read_csv("Data/UNILAK/Sample Points.csv")

# Check column names
print(df.columns)

# indexing
if "index" not in df.columns:
    df["index"] = range(1, len(df) + 1)

plt.figure(figsize=(10, 6)),
plt.plot(df["index"], df["Y1517"], label="Year 2015 & 2017", color="blue", linestyle="-", marker="o")
plt.plot(df["index"], df["Y1921"], label="Year 2019 & 2021", color="red", linestyle="--", marker="s")
plt.plot(df["index"], df["Y2325"], label="Year 2023 & 2025", color="green", linestyle=":", marker="^")

# Formatting
plt.xlabel("Sample Points")
plt.ylabel("Deformation Rate (Meters)")
#plt.title("Trend of Ground Deforemation of Rugongo Mining Site \nYear: 2015 & 2017, 2019 and 2021, 2023 & 2025")
plt.legend( loc = 3)
plt.grid(True)

# Save the figure
plt.savefig('Deformation Trend.png', dpi=1000, bbox_inches='tight')

# Show plot
plt.show()
# Out:
# Index(['S/No', 'Longitude', 'Latitude', 'Y1517', 'Y1921', 'Y2325'], dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# ======================
# 1. Load Data
# ======================
data = {
    'Year': [2016, 2020, 2024],
    'Max': [0.714689, 0.778589, 0.807102],
    'Min': [-0.279102, -0.266297, -0.234552],
    'Mean': [0.30, 0.50, 0.42],
    'Std': [0.09, 0.10, 0.10]
}
df = pd.DataFrame(data)

# ======================
# 2. Statistical Test (ANOVA)
# ======================
# Simulate NDVI data (since we only have summary stats)
np.random.seed(42)
ndvi_2016 = np.random.normal(0.30, 0.09, 100)
ndvi_2020 = np.random.normal(0.50, 0.10, 100)
ndvi_2024 = np.random.normal(0.42, 0.10, 100)

# Perform ANOVA
f_stat, p_value = stats.f_oneway(ndvi_2016, ndvi_2020, ndvi_2024)
print(f"ANOVA Results: F = {f_stat:.2f}, p = {p_value:.3f}")

# ======================
# 3. Visualizations
# ======================
plt.style.use('default')  # Use default matplotlib style

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# ======================
# 1. Load Data
# ======================
data = {
    'Year': [2016, 2020, 2024],
    'Max': [0.714689, 0.778589, 0.807102],
    'Min': [-0.279102, -0.266297, -0.234552],
    'Mean': [0.30, 0.50, 0.42],
    'Std': [0.09, 0.10, 0.10]
}
df = pd.DataFrame(data)

# ======================
# 2. Statistical Test (ANOVA)
# ======================
# Simulate NDVI data (since we only have summary stats)
np.random.seed(42)
ndvi_2016 = np.random.normal(0.30, 0.09, 100)
ndvi_2020 = np.random.normal(0.50, 0.10, 100)
ndvi_2024 = np.random.normal(0.42, 0.10, 100)

# Perform ANOVA
f_stat, p_value = stats.f_oneway(ndvi_2016, ndvi_2020, ndvi_2024)
print(f"ANOVA Results: F = {f_stat:.2f}, p = {p_value:.3f}")

# ======================
# 3. Visualizations
# ======================
plt.style.use('default')  # Use default matplotlib style

# A. Boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(
    [ndvi_2016, ndvi_2020, ndvi_2024],
    labels=['2016', '2020', '2024'],
    patch_artist=True,
    boxprops=dict(facecolor='lightblue', alpha=0.7),
    flierprops=dict(marker='o', markersize=5)
)
plt.title("NDVI Distribution Across Years (Boxplot)", fontsize=14)
plt.ylabel("NDVI Value")
plt.axhline(0, color='red', linestyle='--', label='Vegetation Threshold')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()

# B. Trend Line with Confidence Intervals
plt.figure(figsize=(10, 6))
plt.plot(
    df['Year'],
    df['Mean'],
    marker='o',
    markersize=10,
    linewidth=2.5,
    color='green',
    label='Mean NDVI'
)
plt.fill_between(
    df['Year'],
    df['Mean'] - df['Std'],
    df['Mean'] + df['Std'],
    alpha=0.2,
    color='green',
    label='±1 Std Dev'
)
plt.title("NDVI Trend Over Time with Variability", fontsize=14)
plt.xlabel("Year")
plt.ylabel("NDVI Value")
plt.ylim(-0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend()
plt.show()

# C. Bar Plot with Error Bars
plt.figure(figsize=(10, 6))
plt.bar(
    df['Year'].astype(str),
    df['Mean'],
    yerr=df['Std'],
    capsize=5,
    color=['#1f77b4', '#ff7f0e', '#2ca02c'],
    alpha=0.7
)
plt.title("Mean NDVI with Standard Deviation Error Bars", fontsize=14)
plt.xlabel("Year")
plt.ylabel("NDVI Value")
plt.axhline(0, color='black', linewidth=0.8)
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()
    patch_artist=True,
    boxprops=dict(facecolor='lightblue', alpha=0.7),
    flierprops=dict(marker='o', markersize=5)
plt.title("NDVI Distribution Across Years (Boxplot)", fontsize=14)
plt.ylabel("NDVI Value")
plt.axhline(0, color='red', linestyle='--', label='Vegetation Threshold')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()

# B. Trend Line with Confidence Intervals
plt.figure(figsize=(10, 6))
plt.plot(
    df['Year'],
    df['Mean'],
    marker='o',
    markersize=10,
    linewidth=2.5,
    color='green',
    label='Mean NDVI'
)
plt.fill_between(
    df['Year'],
    df['Mean'] - df['Std'],
    df['Mean'] + df['Std'],
    alpha=0.2,
    color='green',
    label='±1 Std Dev'
)
plt.title("NDVI Trend Over Time with Variability", fontsize=14)
plt.xlabel("Year")
plt.ylabel("NDVI Value")
plt.ylim(-0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend()
plt.show()

# C. Bar Plot with Error Bars
plt.figure(figsize=(10, 6))
plt.bar(
    df['Year'].astype(str),
    df['Mean'],
    yerr=df['Std'],
    capsize=5,
    color=['#1f77b4', '#ff7f0e', '#2ca02c'],
    alpha=0.7
)
plt.title("Mean NDVI with Standard Deviation Error Bars", fontsize=14)
plt.xlabel("Year")
plt.ylabel("NDVI Value")
plt.axhline(0, color='black', linewidth=0.8)
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()
# Out:
#   File "<ipython-input-5-9205d3ad33be>", line 130
#     patch_artist=True,
#     ^
# IndentationError: unexpected indent

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-fe41171d-79f5-4cd9-ae9d-595e90d45b8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe41171d-79f5-4cd9-ae9d-595e90d45b8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Load the data
df = pd.read_csv('Sample Points.csv')

# Classify deformation values
def classify(x):
    if x == 0:
        return 'Stable'
    elif x > 0:
        return 'Uplift'
    else:
        return 'Subsidence'

for col in ['Y1517', 'Y1921', 'Y2325']:
    df[f'{col}_cat'] = df[col].apply(classify)

# Compute category counts for each period
counts = pd.DataFrame({
    '2015-2017': df['Y1517_cat'].value_counts(),
    '2019-2021': df['Y1921_cat'].value_counts(),
    '2023-2025': df['Y2325_cat'].value_counts()
}).T.reset_index().rename(columns={'index': 'Period'})

# Compute descriptive statistics for each period
desc = df[['Y1517', 'Y1921', 'Y2325']].describe().T.reset_index().rename(columns={'index': 'Period'})

# Display results
print("Category Counts by Period:")
display(counts)

print("\nDescriptive Statistics:")
display(desc)

# Create a boxplot for deformation distributions
plt.figure()
df[['Y1517', 'Y1921', 'Y2325']].boxplot()
plt.title('Ground Deformation Distribution of Ruttong Mineing Site Between 2015 to 2025')
plt.xlabel('Period')
plt.ylabel('Deformation (meters)')
plt.grid(True)
plt.show()
# Out:
# Category Counts by Period:
#       Period  Uplift  Subsidence
# 0  2015-2017     570          30
# 1  2019-2021     553          47
# 2  2023-2025     357         243
# Descriptive Statistics:
#   Period  count      mean       std      min       25%      50%       75%  \
# 0  Y1517  599.0  0.218865  0.142394 -0.15434  0.110590  0.21283  0.330895
# 1  Y1921  599.0  0.042328  0.029271 -0.06353  0.022195  0.04351  0.062040
# 2  Y2325  599.0  0.126551  0.463627 -0.88498 -0.264340  0.17515  0.479915
#
#        max
# 0  0.54346
# 1  0.11967
# 2  1.23900

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# Load data
df = pd.read_csv('Sample Points.csv')

# Convert deformation columns to numeric, coercing errors
for col in ['Y1517', 'Y1921', 'Y2325']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Period columns mapping
period_cols = {
    '2015-2017': 'Y1517',
    '2019-2021': 'Y1921',
    '2023-2025': 'Y2325'
}

# Compute ECDF and plot
plt.figure()
for period, col in period_cols.items():
    data = np.sort(df[col].dropna().values)
    ecdf = np.arange(1, len(data) + 1) / len(data)
    plt.step(data, ecdf, where='post', label=period)
plt.title('ECDF of Deformation by Monitoring Period')
plt.xlabel('Deformation (mm)')
plt.ylabel('Empirical Cumulative Distribution')
plt.legend()
plt.grid(True)
plt.show()

# Define quantiles
quantiles = [0, 25, 50, 75, 100]
index_labels = [f"{q}%" for q in quantiles]

# Build quantile table
quantile_vals = {
    period: [df[col].quantile(q/100) for q in quantiles]
    for period, col in period_cols.items()
}
quantile_df = pd.DataFrame(quantile_vals, index=index_labels)

# Display the quantile table
display(quantile_df)
# Out:
#       2015-2017  2019-2021  2023-2025
# 0%    -0.154340  -0.063530  -0.884980
# 25%    0.110590   0.022195  -0.264340
# 50%    0.212830   0.043510   0.175150
# 75%    0.330895   0.062040   0.479915
# 100%   0.543460   0.119670   1.239000

# %%
# Re-import necessary libraries after kernel reset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Reload the data
df = pd.read_csv('Sample Points.csv')

# Convert deformation columns to numeric (in case of issues)
for col in ['Y1517', 'Y1921', 'Y2325']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Classify deformation values
def classify(x):
    if x == 0:
        return 'Stable'
    elif x > 0:
        return 'Uplift'
    else:
        return 'Subsidence'

for col in ['Y1517', 'Y1921', 'Y2325']:
    df[f'{col}_cat'] = df[col].apply(classify)

# Create a combined plot
fig, axs = plt.subplots(1, 2, figsize=(14, 6), dpi=1000)

# Boxplot (Right side)
df[['Y1517', 'Y1921', 'Y2325']].boxplot(ax=axs[1])
axs[1].set_title('Ground Deformation Distribution\nRutongo Mining Site (2015–2025)')
axs[1].set_xlabel('Period (Year:2015-2017, 2019 -2021, 2021 - 2024)')
axs[1].set_ylabel('Deformation (meters)')
axs[1].grid(True)
axs[1].legend()

# ECDF (Left side)
period_cols = {
    '2015-2017': 'Y1517',
    '2019-2021': 'Y1921',
    '2023-2025': 'Y2325'
}
for period, col in period_cols.items():
    data = np.sort(df[col].dropna().values)
    ecdf = np.arange(1, len(data) + 1) / len(data)
    axs[0].step(data, ecdf, where='post', label=period)
axs[0].set_title('ECDF of Ground Deformation Mornitoring \nRutongo Mining Site (2015–2025)')
axs[0].set_xlabel('Deformation (meters)')
axs[0].set_ylabel('Empirical Cumulative Distribution (Meter)')
axs[0].legend()
axs[0].grid(True)

plt.tight_layout()
# Save the figure
plt.savefig('ECDF.png', dpi=1000, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-8-ae655a51785c>:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()

# %%
data = pd.read_csv("Sample Points.csv")
data.head()
# Out:
#    S/No  Longitude  Latitude    Y1517    Y1921    Y2325
# 0     1   30.07563  -1.74483  0.40730  0.08400  0.47002
# 1     2   30.03092  -1.72249  0.47116  0.05821  0.31067
# 2     3   30.05520  -1.73026  0.43017  0.03978  0.84992
# 3     4   30.04052  -1.75010  0.34238  0.04729  0.50453
# 4     5   30.02295  -1.71433  0.46194  0.04906  0.93726

# %%
import pandas as pd
from scipy.stats import wilcoxon

# Load data
df = pd.read_csv('Sample Points.csv')

# Define period-column mapping
pairs = [
    ('2015-2017', '2019-2021', 'Y1517', 'Y1921'),
    ('2015-2017', '2023-2025', 'Y1517', 'Y2325'),
    ('2019-2021', '2023-2025', 'Y1921', 'Y2325'),
]

# Compute Wilcoxon signed-rank test for each paired interval
results = []
for int1, int2, col1, col2 in pairs:
    data = df[[col1, col2]].dropna()
    stat, p = wilcoxon(data[col1], data[col2])
    results.append({
        'Interval 1': int1,
        'Interval 2': int2,
        'Wilcoxon_stat': round(stat, 3),
        'p-value': round(p, 5),
        'Significance (α=0.05)': 'Significant' if p < 0.05 else 'Not significant'
    })

# Create results table
res_df = pd.DataFrame(results)
print("Paired Wilcoxon Signed-Rank Test Results:\n")
print(res_df.to_string(index=False))
# Out:
# Paired Wilcoxon Signed-Rank Test Results:
#
# Interval 1 Interval 2  Wilcoxon_stat  p-value Significance (α=0.05)
#  2015-2017  2019-2021         6029.0  0.00000           Significant
#  2015-2017  2023-2025        67023.0  0.00000           Significant
#  2019-2021  2023-2025        72092.0  0.00003           Significant

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.patches import Patch
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Sample data based on the provided information
# Deformation data (mean values)
deformation_data = {
    'Period': ['2015-2017', '2019-2021', '2023-2025'],
    'Min': [-0.20, -0.12, -1.32],
    'Max': [0.56, 0.15, 1.43],
    'Mean': [0.22, 0.04, 0.14],
    'StdDev': [0.14, 0.03, 0.45]
}

# NDVI data
ndvi_data = {
    'Year': [2016, 2020, 2024],
    'Min': [-0.279102, -0.266297, -0.234552],
    'Max': [0.714689, 0.778589, 0.807102],
    'Mean': [0.30, 0.50, 0.42],
    'StdDev': [0.09, 0.10, 0.10]
}

# Create DataFrames
df_deformation = pd.DataFrame(deformation_data)
df_ndvi = pd.DataFrame(ndvi_data)

# Add estimated EVI data (based on image interpretation)
evi_data = {
    'Year': [2016, 2020, 2024],
    'Min': [-0.10, -0.08, -0.12],
    'Max': [0.65, 0.70, 0.68],
    'Mean': [0.35, 0.45, 0.40],
    'StdDev': [0.08, 0.09, 0.09]
}
df_evi = pd.DataFrame(evi_data)

# Region-specific data (estimated from visual interpretation)
regions = ['Burega', 'Cyinzuzi', 'Ntarabana', 'Masoro', 'Murambi', 'Ngoma']

# Estimated deformation values by region (based on color interpretation from maps)
region_deformation = pd.DataFrame({
    'Region': regions * 3,
    'Period': ['2015-2017'] * 6 + ['2019-2021'] * 6 + ['2023-2025'] * 6,
    'Deformation': [
        0.1, 0.2, 0.3, 0.0, -0.4, -0.5,  # 2015-2017
        0.0, 0.05, 0.1, -0.05, -0.1, -0.1,  # 2019-2021
        0.2, 0.3, 0.1, -0.2, -0.8, -1.0   # 2023-2025
    ]
})

# Estimated NDVI values by region
region_ndvi = pd.DataFrame({
    'Region': regions * 3,
    'Year': [2016] * 6 + [2020] * 6 + [2024] * 6,
    'NDVI': [
        0.5, 0.45, 0.4, 0.35, 0.25, 0.2,  # 2016
        0.6, 0.55, 0.5, 0.45, 0.4, 0.35,  # 2020
        0.55, 0.5, 0.45, 0.4, 0.35, 0.3   # 2024
    ]
})

# Estimated EVI values by region
region_evi = pd.DataFrame({
    'Region': regions * 3,
    'Year': [2016] * 6 + [2020] * 6 + [2024] * 6,
    'EVI': [
        0.45, 0.4, 0.35, 0.3, 0.25, 0.2,  # 2016
        0.55, 0.5, 0.45, 0.4, 0.35, 0.3,  # 2020
        0.5, 0.45, 0.4, 0.35, 0.3, 0.25   # 2024
    ]
})

# Set the style for plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")

# Create a figure for temporal trends
plt.figure(figsize=(14, 8))

# Plot 1: Deformation statistics over time
plt.subplot(2, 2, 1)
x = np.arange(len(df_deformation['Period']))
width = 0.35

plt.bar(x - width/2, df_deformation['Max'], width, label='Max')
plt.bar(x + width/2, df_deformation['Min'], width, label='Min')
plt.plot(x, df_deformation['Mean'], 'ro-', linewidth=2, label='Mean')

plt.xlabel('Period')
plt.ylabel('Deformation (m)')
plt.title('Ground Deformation Statistics Over Time')
plt.xticks(x, df_deformation['Period'])
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Plot 2: NDVI statistics over time
plt.subplot(2, 2, 2)
x = np.arange(len(df_ndvi['Year']))
width = 0.35

plt.bar(x - width/2, df_ndvi['Max'], width, label='Max', color='green')
plt.bar(x + width/2, df_ndvi['Min'], width, label='Min', color='brown')
plt.plot(x, df_ndvi['Mean'], 'bo-', linewidth=2, label='Mean')

plt.xlabel('Year')
plt.ylabel('NDVI Value')
plt.title('NDVI Statistics Over Time')
plt.xticks(x, df_ndvi['Year'])
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Plot 3: Mean values comparison
plt.subplot(2, 1, 2)
years = [2016, 2020, 2024]
deformation_periods = ['2015-2017', '2019-2021', '2023-2025']

width = 0.3
x = np.arange(len(years))

ax1 = plt.gca()
ax2 = ax1.twinx()

bars1 = ax1.bar(x - width, df_ndvi['Mean'], width, color='green', label='NDVI Mean')
bars2 = ax1.bar(x, df_evi['Mean'], width, color='forestgreen', label='EVI Mean', alpha=0.7)
bars3 = ax2.bar(x + width, df_deformation['Mean'], width, color='red', label='Deformation Mean', alpha=0.8)

ax1.set_xlabel('Year')
ax1.set_ylabel('Vegetation Index Value', color='green')
ax2.set_ylabel('Deformation Mean (m)', color='red')
ax1.set_xticks(x)
ax1.set_xticklabels(years)

# Add a second x-axis for deformation periods
ax3 = ax1.twiny()
ax3.set_xlim(ax1.get_xlim())
ax3.set_xticks(x)
ax3.set_xticklabels(deformation_periods)
ax3.set_xlabel('Deformation Period')

# Create a combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.title('Comparison of Vegetation Indices and Deformation Over Time')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Create a new figure for regional analysis
plt.figure(figsize=(15, 12))

# Plot 4: Regional deformation changes
plt.subplot(2, 2, 1)
pivot_def = region_deformation.pivot(index='Region', columns='Period', values='Deformation')
sns.heatmap(pivot_def, cmap='RdBu_r', center=0, annot=True, fmt='.2f',
            linewidths=.5, cbar_kws={'label': 'Deformation (m)'})
plt.title('Regional Deformation Changes Over Time')
plt.ylabel('Region')
plt.xlabel('Period')

# Plot 5: Regional NDVI changes
plt.subplot(2, 2, 2)
pivot_ndvi = region_ndvi.pivot(index='Region', columns='Year', values='NDVI')
sns.heatmap(pivot_ndvi, cmap='YlGn', annot=True, fmt='.2f',
            linewidths=.5, cbar_kws={'label': 'NDVI Value'})
plt.title('Regional NDVI Changes Over Time')
plt.ylabel('Region')
plt.xlabel('Year')

# Plot 6: Regional correlation between deformation and NDVI
plt.subplot(2, 2, 3)
# Merge dataframes for correlation analysis
# Convert years to periods for matching
year_to_period = {2016: '2015-2017', 2020: '2019-2021', 2024: '2023-2025'}
region_ndvi['Period'] = region_ndvi['Year'].map(year_to_period)

merged_data = pd.merge(
    region_deformation,
    region_ndvi,
    on=['Region', 'Period']
)

# Plot correlation
sns.scatterplot(data=merged_data, x='Deformation', y='NDVI', hue='Period',
                style='Region', s=100, palette='viridis')
plt.title('Correlation between Deformation and NDVI by Region')
plt.xlabel('Deformation (m)')
plt.ylabel('NDVI Value')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Plot 7: Time series by region
plt.subplot(2, 2, 4)

for region in regions:
    region_data = region_deformation[region_deformation['Region'] == region]
    plt.plot(region_data['Period'], region_data['Deformation'], 'o-', label=region)

plt.title('Deformation Time Series by Region')
plt.xlabel('Period')
plt.ylabel('Deformation (m)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()

# Create a third figure for spatial visualization (bubble map)
plt.figure(figsize=(18, 6))

# Approximate coordinates (for visualization purposes)
region_coords = {
    'Burega': (0.3, 0.8),
    'Cyinzuzi': (0.4, 0.65),
    'Ntarabana': (0.7, 0.7),
    'Masoro': (0.5, 0.4),
    'Murambi': (0.35, 0.3),
    'Ngoma': (0.2, 0.25)
}

# Add coordinates to dataframes
region_deformation['x'] = region_deformation['Region'].map(lambda r: region_coords[r][0])
region_deformation['y'] = region_deformation['Region'].map(lambda r: region_coords[r][1])
region_ndvi['x'] = region_ndvi['Region'].map(lambda r: region_coords[r][0])
region_ndvi['y'] = region_ndvi['Region'].map(lambda r: region_coords[r][1])

# Plot bubble maps for each period
periods = ['2015-2017', '2019-2021', '2023-2025']
for i, period in enumerate(periods):
    plt.subplot(1, 3, i+1)

    # Filter data for the period
    period_def = region_deformation[region_deformation['Period'] == period]
    period_ndvi = region_ndvi[region_ndvi['Period'] == period]

    # Plot base map (simple rectangle)
    plt.plot([0, 1, 1, 0, 0], [0, 0, 1, 1, 0], 'k-', alpha=0.3)

    # Plot deformation bubbles
    scatter = plt.scatter(
        period_def['x'], period_def['y'],
        s=abs(period_def['Deformation'])*500 + 100,
        c=period_def['Deformation'],
        cmap='RdBu_r',
        alpha=0.7,
        edgecolor='black',
        vmin=-1.0, vmax=1.0
    )

    # Add region labels
    for _, row in period_def.iterrows():
        plt.text(row['x'], row['y'], row['Region'],
                 ha='center', va='center', fontsize=8, weight='bold')

    # Add color bar
    divider = make_axes_locatable(plt.gca())
    cax = divider.append_axes("right", size="5%", pad=0.1)
    plt.colorbar(scatter, cax=cax, label='Deformation (m)')

    plt.title(f'Spatial Deformation Pattern ({period})')
    plt.xlim(-0.1, 1.1)
    plt.ylim(-0.1, 1.1)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# Create a fourth figure for relationship visualization
plt.figure(figsize=(16, 8))

# Plot 8: Combined trend visualization
plt.subplot(1, 2, 1)
x = np.arange(3)
width = 0.25

# Normalized values for comparison
norm_deformation = df_deformation['Mean'] / max(abs(df_deformation['Mean']))
norm_ndvi = (df_ndvi['Mean'] - min(df_ndvi['Mean'])) / (max(df_ndvi['Mean']) - min(df_ndvi['Mean']))
norm_evi = (df_evi['Mean'] - min(df_evi['Mean'])) / (max(df_evi['Mean']) - min(df_evi['Mean']))

plt.bar(x - width, norm_deformation, width, label='Deformation (normalized)', color='red', alpha=0.7)
plt.bar(x, norm_ndvi, width, label='NDVI (normalized)', color='green', alpha=0.7)
plt.bar(x + width, norm_evi, width, label='EVI (normalized)', color='blue', alpha=0.7)

plt.xlabel('Time Period')
plt.ylabel('Normalized Value')
plt.title('Normalized Comparison of Deformation and Vegetation Indices of Rutunog Mining Site')
plt.xticks(x, ['2015-2017/2016', '2019-2021/2020', '2023-2025/2024'])
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Plot 9: Conceptual model of relationship
plt.subplot(1, 2, 2)

# Create a conceptual diagram
def sigmoid(x, a=1, b=0, c=1, d=0):
    return c / (1 + np.exp(-a * (x - b))) + d

x = np.linspace(-2, 2, 100)
y1 = sigmoid(x, a=-2, b=0, c=-0.6, d=0.8)  # NDVI response to deformation
y2 = sigmoid(x, a=-2.5, b=0.2, c=-0.7, d=0.9)  # EVI response to deformation

plt.plot(x, y1, 'g-', linewidth=3, label='NDVI Response')
plt.plot(x, y2, 'b-', linewidth=3, label='EVI Response')

# Add threshold line
plt.axvline(x=0.5, color='red', linestyle='--', alpha=0.7, label='Deformation Threshold')

# Add arrows and annotations
plt.annotate('Recovery Zone', xy=(-1, 0.7), xytext=(-1.5, 0.9),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8),
            fontsize=10, ha='center')

plt.annotate('Impact Zone', xy=(1, 0.3), xytext=(1.5, 0.1),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8),
            fontsize=10, ha='center')

plt.xlabel('Ground Deformation Intensity')
plt.ylabel('Vegetation Health')
plt.title('Conceptual Model of Vegetation Response to Ground Deformation')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()

# Save all figures
plt.figure(1)
plt.savefig('temporal_trends.png', dpi=300, bbox_inches='tight')

plt.figure(2)
plt.savefig('regional_analysis.png', dpi=300, bbox_inches='tight')

plt.figure(3)
plt.savefig('spatial_patterns.png', dpi=300, bbox_inches='tight')

plt.figure(4)
plt.savefig('relationship_model.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")

# Sample data based on the provided information
# Deformation data (mean values)
deformation_data = {
    'Period': ['2015-2017', '2019-2021', '2023-2025'],
    'Min': [-0.20, -0.12, -1.32],
    'Max': [0.56, 0.15, 1.43],
    'Mean': [0.22, 0.04, 0.14],
    'StdDev': [0.14, 0.03, 0.45]
}

# NDVI data
ndvi_data = {
    'Year': [2016, 2020, 2024],
    'Min': [-0.279102, -0.266297, -0.234552],
    'Max': [0.714689, 0.778589, 0.807102],
    'Mean': [0.30, 0.50, 0.42],
    'StdDev': [0.09, 0.10, 0.10]
}

# Add EVI data (based on image interpretation)
evi_data = {
    'Year': [2016, 2020, 2024],
    'Min': [-0.10, -0.08, -0.12],
    'Max': [0.65, 0.70, 0.68],
    'Mean': [0.35, 0.45, 0.40],
    'StdDev': [0.08, 0.09, 0.09]
}

# Create DataFrames
df_deformation = pd.DataFrame(deformation_data)
df_ndvi = pd.DataFrame(ndvi_data)
df_evi = pd.DataFrame(evi_data)

# Create a figure for relationship visualization
plt.figure(figsize=(16, 8))

# Plot 1: Combined trend visualization
plt.subplot(1, 2, 1)
x = np.arange(3)
width = 0.25

# Fixed normalization to ensure all values are visible
# For deformation: normalize to the maximum absolute value
max_def_abs = max(abs(df_deformation['Mean'].max()), abs(df_deformation['Mean'].min()))
norm_deformation = df_deformation['Mean'] / max_def_abs

# For NDVI: normalize to the range between min and max
norm_ndvi = (df_ndvi['Mean'] - df_ndvi['Mean'].min()) / (df_ndvi['Mean'].max() - df_ndvi['Mean'].min())

# For EVI: normalize to the range between min and max
norm_evi = (df_evi['Mean'] - df_evi['Mean'].min()) / (df_evi['Mean'].max() - df_evi['Mean'].min())

# Ensure all metrics have values for all periods
plt.bar(x - width, norm_deformation, width, label='Deformation (normalized)', color='red')
plt.bar(x, norm_ndvi, width, label='NDVI (normalized)', color='green')
plt.bar(x + width, norm_evi, width, label='EVI (normalized)', color='blue')

plt.xlabel('Time Period', fontsize=12)
plt.ylabel('Normalized Value', fontsize=12)
plt.title('Normalized Comparison of Deformation and Vegetation Indices of Rutongo Mining Site', fontsize=14)
plt.xticks(x, ['2015-2017/2016', '2019-2021/2020', '2023-2025/2024'], fontsize=10)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)

# Plot 2: Conceptual model of relationship
plt.subplot(1, 2, 2)

# Create a sigmoid function for conceptual model
def sigmoid(x, a=1, b=0, c=1, d=0):
    return c / (1 + np.exp(-a * (x - b))) + d

# Create data for the conceptual model
x = np.linspace(-2, 2, 100)

# Adjusted parameters to match the desired visualization
# For NDVI: ascending curve from low to high with deformation
y_ndvi = sigmoid(x, a=1.8, b=0, c=0.58, d=0.21)  # Green line in your example

# For EVI: steeper curve with slightly higher values
y_evi = sigmoid(x, a=2.2, b=0, c=0.68, d=0.20)   # Blue line in your example

# Plot the curves
plt.plot(x, y_ndvi, 'g-', linewidth=2.5, label='NDVI Response')
plt.plot(x, y_evi, 'b-', linewidth=2.5, label='EVI Response')

# Add threshold line at x=0.5
plt.axvline(x=0.5, color='red', linestyle='--', alpha=0.7, label='Deformation Threshold')

# Add arrows and annotations
plt.annotate('Recovery Zone', xy=(-1.5, 0.75), xytext=(-1.5, 0.88),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8),
            fontsize=10, ha='center')

plt.annotate('Impact Zone', xy=(1.5, 0.3), xytext=(1.5, 0.18),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8),
            fontsize=10, ha='center')

plt.xlabel('Ground Deformation Intensity', fontsize=12)
plt.ylabel('Vegetation Health', fontsize=12)
plt.title('Conceptual Model of Vegetation Response to Ground Deformation', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(-2.1, 2.1)
plt.ylim(0.18, 0.92)

plt.tight_layout()

# Save the figure
plt.savefig('deformation_vegetation_relationship.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")

# Sample data
deformation_data = {
    'Period': ['2015-2017', '2019-2021', '2023-2025'],
    'Mean': [0.22, 0.04, 0.14]
}

ndvi_data = {
    'Year': [2016, 2020, 2024],
    'Mean': [0.30, 0.50, 0.42]
}

evi_data = {
    'Year': [2016, 2020, 2024],
    'Mean': [0.35, 0.45, 0.40]
}

# Create DataFrames
df_def = pd.DataFrame(deformation_data)
df_ndvi = pd.DataFrame(ndvi_data)
df_evi = pd.DataFrame(evi_data)

# Normalization: divide by maximum mean value
norm_def = df_def['Mean'] / df_def['Mean'].max()
norm_ndvi = df_ndvi['Mean'] / df_ndvi['Mean'].max()
norm_evi = df_evi['Mean'] / df_evi['Mean'].max()

# Create the figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

# Subplot 1: Normalized bar chart
x = np.arange(3)
width = 0.25

axs[0].bar(x - width, norm_def, width, label='Deformation (normalized)', color='red')
axs[0].bar(x, norm_ndvi, width, label='NDVI (normalized)', color='green')
axs[0].bar(x + width, norm_evi, width, label='EVI (normalized)', color='blue')

axs[0].set_xlabel('Time Period')
axs[0].set_ylabel('Normalized Value')
axs[0].set_title('Normalized Comparison of Deformation and Vegetation Indices')
axs[0].set_xticks(x)
axs[0].set_xticklabels(['2015-2017/2016', '2019-2021/2020', '2023-2025/2024'])
axs[0].legend()
axs[0].grid(True, linestyle='--', alpha=0.7)

# Subplot 2: Conceptual model of vegetation response
def sigmoid(x, a=1, b=0, c=1, d=0):
    return c / (1 + np.exp(-a * (x - b))) + d

x_vals = np.linspace(-2, 2, 100)
y_ndvi = sigmoid(x_vals, a=1.8, b=0, c=0.58, d=0.21)
y_evi = sigmoid(x_vals, a=2.2, b=0, c=0.68, d=0.20)

axs[1].plot(x_vals, y_ndvi, 'g-', linewidth=2.5, label='NDVI Response')
axs[1].plot(x_vals, y_evi, 'b-', linewidth=2.5, label='EVI Response')
axs[1].axvline(x=0.5, color='red', linestyle='--', alpha=0.7, label='Deformation Threshold')

axs[1].annotate('Recovery Zone', xy=(-1.5, 0.75), xytext=(-1.5, 0.88),
                arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8),
                fontsize=10, ha='center')
axs[1].annotate('Impact Zone', xy=(1.5, 0.3), xytext=(1.5, 0.18),
                arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8),
                fontsize=10, ha='center')

axs[1].set_xlabel('Ground Deformation Intensity')
axs[1].set_ylabel('Vegetation Health')
axs[1].set_title('Conceptual Model of Vegetation Response to Ground Deformation')
axs[1].legend()
axs[1].grid(True, linestyle='--', alpha=0.7)
axs[1].set_xlim(-2.1, 2.1)
axs[1].set_ylim(0.18, 0.92)

plt.tight_layout()
# Save the figure
plt.savefig('DeVeg_relationship.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data
df = pd.read_csv('Sample Points.csv')

# Melt the three deformation columns into a long format
mapping = {'Y1517': 2016, 'Y1921': 2020, 'Y2325': 2024}
df_long = df.melt(value_vars=['Y1517','Y1921','Y2325'],
                  var_name='Period',
                  value_name='Deformation')
df_long['Year'] = df_long['Period'].map(mapping)

# Create the time‑series scatter + smoothed curve
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_long, x='Year', y='Deformation', alpha=0.5)
sns.regplot(data=df_long, x='Year', y='Deformation',
            lowess=True, scatter=False, color='purple', line_kws={'linewidth':2})

plt.title('Ground Deformation Time Series at Rutongo Mine (2015–2025)')
plt.xlabel('Year')
plt.ylabel('Deformation (mm)')
plt.xlim(2015, 2025)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(10, 6))

# Boxplot to show the distribution per year
sns.boxplot(data=df_long, x='Year', y='Deformation', whis=1.5, width=0.4, palette='Set3', showfliers=False)

# Stripplot to show individual points with jitter
sns.stripplot(data=df_long, x='Year', y='Deformation', color='black', alpha=0.6, jitter=0.25)

# Titles and labels
plt.title('Deformation Rate Distribution Over Time at Rutongo Mine')
plt.xlabel('Year')
plt.ylabel('Deformation (mm)')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-3-b969f01b01f0>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_long, x='Year', y='Deformation', whis=1.5, width=0.4, palette='Set3', showfliers=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Reload the dataset
df = pd.read_csv('Sample Points.csv')

# Set the style
sns.set(style="whitegrid")

# Create violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(data=df_long, x='Year', y='Deformation', inner='box', palette='muted')

# Titles and labels
plt.title('Violin Plot of Deformation Rate Over Time at Rutongo Mine')
plt.xlabel('Year')
plt.ylabel('Deformation (mm)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-97ec5034f8bd>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_long, x='Year', y='Deformation', inner='box', palette='muted')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data (update path if needed)
df = pd.read_csv("Sample Points.csv")

# Reshape the data into long format
long_df = pd.melt(df,
                  id_vars=['S/No'],
                  value_vars=['Y1517', 'Y1921', 'Y2325'],
                  var_name='Period',
                  value_name='Deformation')

# Map periods to actual years (approximate mid-year representation)
year_map = {'Y1517': 2016, 'Y1921': 2020, 'Y2325': 2024}
long_df['Year'] = long_df['Period'].map(year_map)

# Set style
sns.set(style="whitegrid")

# Scatter plot with jitter to show point density
plt.figure(figsize=(10, 6))
sns.stripplot(data=long_df, x='Year', y='Deformation', jitter=0.2, palette="viridis", size=6)

plt.title("Scatter Plot of Deformation Rate Over Time", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Deformation Rate", fontsize=12)
plt.xticks([2016, 2020, 2024])
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-63a6a2640313>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=long_df, x='Year', y='Deformation', jitter=0.2, palette="viridis", size=6)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reshape the data into long format
long_df = pd.melt(df,
                  id_vars=['S/No'],
                  value_vars=['Y1517', 'Y1921', 'Y2325'],
                  var_name='YearGroup',
                  value_name='DeformationRate')

# Map year groups to readable labels (optional)
year_labels = {'Y1517': '2015–2017', 'Y1921': '2019–2021', 'Y2325': '2023–2025'}
long_df['YearGroup'] = long_df['YearGroup'].map(year_labels)

# Scatter-style plot
plt.figure(figsize=(10, 6))
sns.stripplot(data=long_df, x='YearGroup', y='DeformationRate', jitter=True, size=6, alpha=0.7)
plt.title('Scatter Plot of Deformation Rate Over Time')
plt.xlabel('Year Group')
plt.ylabel('Deformation Rate (mm/year or unit)')
plt.grid(True)
plt.tight_layout()
plt.show()
